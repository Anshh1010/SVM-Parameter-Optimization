# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import random
import os, sys, time, threading, multiprocessing

# %%
df=pd.read_excel('/Users/anshhchaturvedi/Desktop/Data_Science/PA_5/Dry_Bean_Dataset.xlsx')

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
print(df['Class'].value_counts())
# Out:
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: Class, dtype: int64

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
df['Class'].replace(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ','SIRA','DERMASON'],
                        [0, 1 ,2 ,3 ,4, 5,6], inplace=True)

# %%
samples = []
for i in range(40):
    X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1], df.iloc[:, -1], test_size=0.3)
    samples.append((X_train, X_test, y_train, y_test))

# %%
samples
accuracies = []
accuracies2=[]

# %%
def task(cmd):
    iteration= 2
    bestAccuracy=0
    kernelList = ['linear','rbf', 'sigmoid']
    X_train, X_test, y_train, y_test = cmd
    for j in range(1, iteration+1):
            print("iteration ",j)
            kernel= np.random.choice(kernelList)
            c = np.random.uniform(0,10)
            gamma = np.random.uniform(0, 10)
            print(kernel , c, gamma)
            model= svm.SVC( C= c, kernel= kernel, gamma=gamma)
            model.fit(X_train, y_train)
            print("fit")
            predicted = model.predict(X_test)
            accuracy = round(np.mean(y_test == predicted) * 100, 2)
            if accuracy > bestAccuracy:
                bestAccuracy = accuracy
    accuracies.append(bestAccuracy)

# %%
nsamples = 15

times20=[]
times40=[]
numberOfThreads = 4
activeThreads = threading.active_count()

for k in range(numberOfThreads):
    starttime=time.time()
    activeThreads = threading.active_count()
    for i in range(nsamples):
        
        
        cmd=samples[i]
    
        print("Iterating on sample ", i+1)
        t = threading.Thread(target=task , args=(cmd,))
        t.start()
        while True:
            if threading.active_count() - activeThreads + 1 <= k+1:
               break
            time.sleep(1)
        if(i==20):
            times20.append(time.time()-starttime)
    while True:
       if threading.active_count() == activeThreads:
        break
       else:
        print ("    Thread still running (left %d)..."%(threading.active_count() - activeThreads))
        time.sleep(1)
  
      
        
    times40.append(time.time()-starttime)    
    accuracies2.append(accuracies) 
        
print("Done iterating!\n")
# Out:
# Iterating on sample  1
# iteration  1
# rbf 2.314138563585253 2.2283449376207907
# fit
# iteration  2
# linear 2.392332404679599 5.0668208111667115
# fit
# Iterating on sample  2
# iteration  1
# rbf 7.369056139707094 2.8797456828266297
# fit
# iteration  2
# sigmoid 0.6863572404804752 1.182813987789345
# fit
# Iterating on sample  3
# iteration  1
# sigmoid 9.648722458047102 5.686305430531345
# fit
# iteration  2
# rbf 8.393154163485963 3.690136434629573
# fit
# Iterating on sample  4
# iteration  1
# sigmoid 9.538911525169112 2.9271743774320202
# fit
# iteration  2
# linear 7.503289749202638 8.556845208840553
# fit
# Iterating on sample  5
# iteration  1
# sigmoid 4.571259695733008 7.515415770174512
# fit
# iteration  2
# rbf 7.773962782172031 3.7149526069494088
# fit
# Iterating on sample  6
# iteration  1
# rbf 5.577046737700585 2.022790487545695
# fit
# iteration  2
# sigmoid 3.3473334963871104 7.8841852308698135
# fit
# Iterating on sample  7
# iteration  1
# rbf 8.6837177821205 8.734758460904091
# fit
# iteration  2
# sigmoid 2.4382535826557508 5.972977065274749
# fit
# Iterating on sample  8
# iteration  1
# rbf 2.2185276326048187 1.5671382412069879
# fit
# iteration  2
# linear 9.068045475593978 9.968815591446099
# fit
# Iterating on sample  9
# iteration  1
# sigmoid 4.477842162657283 0.24024482236578937
# fit
# iteration  2
# rbf 4.3092808299055445 5.522754247002222
# fit
# Iterating on sample  10
# iteration  1
# rbf 5.292545759289507 5.565273915659239
# fit
# iteration  2
# rbf 1.1149658717359046 1.225975646975337
# fit
# Iterating on sample  11
# iteration  1
# linear 9.736878076906365 2.3395615855543594
# fit
# iteration  2
# sigmoid 9.065049187256127 6.822121900550457
# fit
# Iterating on sample  12
# iteration  1
# linear 3.9922784633343813 6.226715527742115
# fit
# iteration  2
# sigmoid 9.612514194142271 9.484151418335308
# fit
# Iterating on sample  13
# iteration  1
# sigmoid 3.9242735708763297 3.5628047582092846
# fit
# iteration  2
# rbf 6.376947339231212 3.1442260277067025
# fit
# Iterating on sample  14
# iteration  1
# rbf 3.8846912978062456 1.996816003298716
# fit
# iteration  2
# sigmoid 8.969303885333455 4.4861856644343
# fit
# Iterating on sample  15
# iteration  1
# linear 5.691926629002991 0.9056071130478427
# fit
# iteration  2
# rbf 4.426069147798071 8.786046105805143
# fit
# Iterating on sample  1
# iteration  1
# rbf 7.19084442241463 7.311654747808295
# Iterating on sample  2
# iteration  1
# rbf 0.042452364131144726 6.731731393661668
# fit
# fit
# iteration  2
# sigmoid 0.9507381807135606 2.2391344309100845
# iteration  2
# linear 1.4086338941006793 6.336085295514473
# fit
# Iterating on sample  3
# iteration  1
# linear 5.343285753815334 4.2536164631098785
# fit
# iteration  2
# linear 9.850034799270652 5.252407045339943
# fit
# Iterating on sample  4
# iteration  1
# rbf 7.372976821386267 1.7563810642615607
# fit
# iteration  2
# linear 7.73783744340148 3.013495536061569
# fit
# Iterating on sample  5
# iteration  1
# sigmoid 3.3677224454969723 8.186692719531878
# fit
# iteration  2
# sigmoid 3.8818299186990677 9.80138069982619
# fit
# Iterating on sample  6
# iteration  1
# sigmoid 2.305430247515632 5.185120023143473
# fit
# iteration  2
# sigmoid 3.6528892153499317 9.117275206076291
# fit
# Iterating on sample  7
# iteration  1
# sigmoid 0.4603205312327552 6.606376776442675
# fit
# iteration  2
# sigmoid 1.7964394298877917 4.8550909195147
# fit
# Iterating on sample  8
# iteration  1
# linear 4.902129569838931 5.939518155478437
# fit
# Iterating on sample  9
# iteration  1
# rbf 0.0513336628477723 6.720367947588444
# fit
# iteration  2
# rbf 4.391973982443767 5.0295385977448595
# fit
# Iterating on sample  10
# iteration  1
# rbf 2.245534931436782 3.1579626440908237
# fit
# iteration  2
# rbf 0.15734103947396272 3.0869316955622175
# fit
# Iterating on sample  11
# iteration  1
# linear 2.2623748867890825 0.43661542885955695
# fit
# iteration  2
# sigmoid 2.444046920289197 0.49612927044279664
# fit
# Iterating on sample  12
# iteration  1
# sigmoid 2.1279709788001377 4.2012779060835275
# fit
# iteration  2
# rbf 2.424030275790167 0.9630128823802075
# fit
# Iterating on sample  13
# iteration  1
# rbf 4.660368104189193 5.359587709552263
# fit
# iteration  2
# sigmoid 5.893650809627666 6.265631131568861
# fit
# Iterating on sample  14
# iteration  1
# rbf 6.866578588334324 5.334716191117272
# fit
# fit
# iteration  2
# sigmoid 3.879810009770155 6.090890434239267
# iteration  2
# sigmoid 1.8233804626788452 6.920831762541483
# fit
# fit
# Iterating on sample  15
# iteration  1
# linear 9.116982426388578 9.720767817807435
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# fit
# iteration  2
# linear 9.282043905241558 1.7110753964934577
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# fit
# Iterating on sample  1
# iteration  1
# rbf 0.09295564330041528 2.3534586459054694
# Iterating on sample  2
# iteration  1
# linear 9.25684188701518 9.211816265275322
# Iterating on sample  3
# iteration  1
# sigmoid 0.20786043531780263 5.550952801563973
# fit
# iteration  2
# linear 8.475942972711948 0.4481613495733128
# fit
# iteration  2
# sigmoid 6.4458219268056585 8.17497369122117
# fit
# Iterating on sample  4
# iteration  1
# linear 1.3051378092534838 5.746179983841785
# fit
# iteration  2
# rbf 9.252572646870775 7.2435344102151795
# fit
# Iterating on sample  5
# iteration  1
# sigmoid 8.43910039433964 3.752796277786076
# fit
# Iterating on sample  6
# iteration  1
# sigmoid 7.646010757530793 3.175799145948278
# fit
# iteration  2
# linear 0.17023862580874405 4.587533945892252
# fit
# iteration  2
# rbf 0.7340091648974212 4.692236213892311
# fit
# iteration  2
# linear 6.989656734364683 8.526315517126328
# fit
# Iterating on sample  7
# iteration  1
# sigmoid 8.697275660994524 1.0314392009429196
# fit
# iteration  2
# linear 9.79203916193646 9.20036934441825
# fit
# Iterating on sample  8
# iteration  1
# sigmoid 9.840413191225077 1.6414749417518548
# fit
# iteration  2
# sigmoid 2.8856826226278995 5.67417974436302
# fit
# Iterating on sample  9
# iteration  1
# rbf 5.509935890020773 4.464579228075637
# fit
# fit
# Iterating on sample  10
# iteration  1
# sigmoid 2.003325242069195 8.79580562552776
# iteration  2
# rbf 9.21434384978751 7.804667138742383
# fit
# iteration  2
# sigmoid 7.683051462127652 2.736820902615084
# fit
# fit
# Iterating on sample  11
# iteration  1
# rbf 6.137649515069649 3.7656412804100006
# Iterating on sample  12
# iteration  1
# linear 2.355717748204589 3.019553648274943
# fit
# iteration  2
# linear 0.48856721684625626 9.752686216098786
# fit
# Iterating on sample  13
# iteration  1
# rbf 7.215752783646647 0.2251711609876994
# fit
# iteration  2
# sigmoid 4.076013908908287 6.153144145284144
# fit
# Iterating on sample  14
# iteration  1
# linear 8.788620372991758 6.047603435721677
# fit
# iteration  2
# rbf 5.056613906512734 6.76559144017858
# fit
# fit
# Iterating on sample  15
# iteration  1
# sigmoid 9.337029432189727 2.2628100996905944
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
# fit
# iteration  2
# sigmoid 7.434763576577793 2.9050313813333926
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
# fit
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# fit
# iteration  2
# rbf 0.31659856806666165 1.8930307085026932
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# fit
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# Iterating on sample  1
# iteration  1
# sigmoid 6.2684272399105145 5.733013667973861
# Iterating on sample  2
# iteration  1
# linear 0.26734527742647285 1.6980971275498946
# Iterating on sample  3
# iteration  1
# sigmoid 6.534069738989113 8.30045392445557
# Iterating on sample  4
# iteration  1
# rbf 3.66674379799814 7.611409502735804
# fit
# fit
# iteration  2
# sigmoid 2.7444673422367383 9.138890905001576
# iteration  2
# rbf 9.263628804217452 6.036607344261956
# fit
# fit
# Iterating on sample  5
# iteration  1
# linear 6.945795885697519 2.4288701946381663
# iteration  2
# sigmoid 8.12503084343733 8.423547520194143
# fit
# fit
# Iterating on sample  6
# iteration  1
# rbf 0.7245703174695062 6.877155293516143
# Iterating on sample  7
# iteration  1
# linear 6.579792217791944 7.101956200159193
# fit
# iteration  2
# rbf 5.116471560951399 0.8439212285853759
# fit
# fit
# iteration  2
# rbf 8.685598948992519 4.439671317352697
# Iterating on sample  8
# iteration  1
# linear 3.8963107622746582 3.7047351615837876
# fit
# Iterating on sample  9
# iteration  1
# linear 0.6989873351681386 8.16894974009702
# fit
# iteration  2
# linear 7.512284505214206 3.3506021128376395
# fit
# iteration  2
# linear 1.5014463866861227 7.29176043396699
# fit
# Iterating on sample  10
# iteration  1
# sigmoid 2.038417013171067 1.0346264120461757
# fit
# iteration  2
# rbf 0.61788296865803 1.3655381485305995
# fit
# fit
# iteration  2
# rbf 3.718103605230497 7.8193334326022
# iteration  2
# linear 9.993096612749824 6.406185100849124
# fit
# fit
# Iterating on sample  11
# iteration  1
# rbf 3.9098690447633864 6.011610565279096
# Iterating on sample  12
# iteration  1
# linear 4.484264002034887 8.837972204795632
# fit
# iteration  2
# sigmoid 3.102060354820307 1.8653024866403356
# fit
# Iterating on sample  13
# iteration  1
# linear 4.419444654262387 7.228121206522184
# fit
# Iterating on sample  14
# iteration  1
# sigmoid 7.369096826995497 2.977380731702656
# fit
# iteration  2
# sigmoid 7.085511843205929 1.6038154786340397
# fit
# fit
# Iterating on sample  15
# iteration  1
# rbf 9.481532159888687 8.926488724434037
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
# fit
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
# iteration  2
# rbf 7.047107289074504 2.411176129908376
#     Thread still running (left 3)...
# fit
# iteration  2
# linear 6.47392160914527 2.5427350758569043
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
# fit
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 3)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
#     Thread still running (left 2)...
# fit
# iteration  2
# sigmoid 9.906796013676779 2.9734108216171284
#     Thread still running (left 2)...
#     Thread still running (left 2)...
# fit
#     Thread still running (left 2)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
#     Thread still running (left 1)...
# fit
# Done iterating!

# %%
times40
# Out:
# [299.3821349143982, 214.26274991035461, 189.6983950138092, 186.73430824279785]
